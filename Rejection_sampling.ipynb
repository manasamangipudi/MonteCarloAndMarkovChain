# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeja-g/sampling_mc/blob/master/Rejection_sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rejection Sampling

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
x = np.arange(-50, 150)

# %%
def f(x):
    return st.norm.pdf(x, loc=30, scale=10) + st.norm.pdf(x, loc=80, scale=20)

def g(x):
    return st.norm.pdf(x, loc=50, scale=30)

# %%
k = max(f(x) / g(x))

# %%
plt.plot(x, f(x), label="$F(x)$")
plt.plot(x, g(x), label="$G(x)$")
plt.plot(x, k*g(x), label="$k*G(x)$")

plt.xlabel("x", size=18)
plt.ylabel("y", size=18)
plt.legend(loc='best')
plt.show()

# %%
def rejection_sampling(iter=1000):

    samples = []

    for i in range(iter):
        z = np.random.normal(50, 30)
        u = np.random.uniform(0, k*g(z))

        if u <= f(z):
            samples.append(z)

    return np.array(samples)

# %%
sns.distplot(rejection_sampling(iter=100000))
